# %% [markdown]
# # MNIST

# %% [markdown]
# ### MNIST 데이터 받기

# %%
import os
import sys
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

mnist = input_data.read_data_sets("data/", one_hot=True)
train_data = mnist.train.images
train_label = mnist.train.labels
test_data = mnist.test.images
test_label = mnist.test.labels
# Out:
# WARNING:tensorflow:From <ipython-input-1-76cba88990fd>:9: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /home/pirl/anaconda3/envs/TF/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /home/pirl/anaconda3/envs/TF/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /home/pirl/anaconda3/envs/TF/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/pirl/anaconda3/envs/TF/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting data/t10k-images-idx3-ubyte.gz
# Extracting data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/pirl/anaconda3/envs/TF/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %% [markdown]
# ### MNIST 데이터 확인하기

# %%
# size of MNIST
print(train_data.shape)
print(train_label.shape)
print(test_data.shape)
print(test_label.shape)
# Out:
# (55000, 784)
# (55000, 10)
# (10000, 784)
# (10000, 10)

# %% [markdown]
# ### Data Pre-processing (데이터 전처리)

# %% [markdown]
# # Implementation (1)
#
#
# ## Loss function (손실 함수) : Cross Entropy
#
# # <center> \\( L(y_i, f(x_i; W)) = -\frac{1}{n}\sum_{i=1}^{n}\sum_{k=1} y_{i,j} log(f(x_i)_k)\\)</center>
#
#
# #### get_cross_entropy_loss 함수의 내용을 완성하세요.
# #### (Hint : (1) tf.reduce_mean(), tf.reduce_sum(), tf.log() (2) Tensor dimension에 유의 (3) log 함수 사용 시 epsilon 사용하세요.)

# %%
def get_cross_entropy_loss(y_true, y_hat, epsilon=1e-8):
    """
    compute cross entropy

    Args:
        y_true: true label
        y_hat: predicted label
        epsilon: small value to prevent NaN in log

    Returns:
        cross entropy loss
    """
    with tf.name_scope('cross_entropy'):
        ###################################################################
        #                    Implementation 1                             #
        ###################################################################
        loss = tf.reduce_mean(-tf.reduce_sum(y_true * tf.log(y_hat), axis = 1))
    
    
    return loss

def get_accuracy(y_true, y_hat):
    """
    compute cross entropy

    Args:
        y_true: true label
        y_hat: predicted label
        epsilon: small value to prevent NaN in log

    Returns:
        cross entropy loss
    """
    with tf.name_scope('accuracy'):
        # Compare the highest indices between the predicted label and the true label
        correct_prediction = tf.equal(tf.argmax(y_hat, 1), tf.argmax(y_true, 1), name='correct_prediction')
        # Compute accuracy
        accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32), name='accuracy')
    return accuracy

# %% [markdown]
# ## Hyper-parameter (하이퍼 파라미터)

# %%
# Set hypyerparameters
learning_rate = 0.001
max_iter = 2000
batch_size = 100

# %% [markdown]
# # Implementation (2)
# ## Linear Classifier (선형 분류기)
#
# ## <center> \\( f(x) = W^Tx+b \\)</center>
#
# ### linear function을 완성하세요.
# ### (Hint : (1) weight, bias 선언 (2) tf.get_variable()의 initializer  (3) tf.matmul())

# %%
def fc(name, out_dim, inputs):
    """
    Args :
        Inputs : Input tensor
        out_dim : output dimension
        
    Returns:
        inputs * weight + bias
    """
    with tf.variable_scope(name):
        ###################################################################
        #                    Implementation 2                             #
        ###################################################################
        shp = inputs.get_shape().as_list()[-1]
        init = tf.truncated_normal([shp, out_dim], stddev=.01)
        weight = tf.get_variable('w', initializer=init)
        
        init = tf.constant(1.0, shape=[out_dim])
        bias = tf.get_variable('b', initializer=init)
        
        result = tf.matmul(inputs, weight) + bias
    
    return result

# %% [markdown]
# # Implementation (3)
#
# ## Model Setting
#
# ### 1. Training data 및 Test data의 각각의 image를 한 vector로 만들어서 train_data, test_data에 각각 저장하세요.
# #### Hint) 데이터 차원.
# ### 2. Dataset로부터 받은 데이터(Image, label)를 담을 변수를 각각 x 및 y_true에 선언하세요.
# #### Hint) tf.placeholder
# ### 3. Implementation (2)에서 구현한 linear classifier 함수값과 softmax 함수를 통한 prediction 값을 y_hat에 저장하세요.
# #### Hint) tf.nn.softmax
# ### 4. 3으로부터 얻은 결과를 통해 Implementation (1)에서 구현한 loss function을 통해 얻은 loss를 cross_entropy에 저장하세요.

# %%
tf.reset_default_graph()
# Flatten data
###################################################################
#                    Implementation 3-1                           #
###################################################################
# train_data = None
# test_data = None

###################################################################
#                    Implementation 3-2                           #
###################################################################

x = tf.placeholder(tf.float32, [None, 784]) # 배치사이즈로 넣어줄 거라서 앞의 shape 는 None 이 된다.
y_true = tf.placeholder(tf.float32, [None, 10])

###################################################################
#                    Implementation 3-3                          #
###################################################################
h1 = fc('layer1', 512, x)
h1 = tf.nn.relu(h1)
h2 = fc('layer2', 64, h1)
h2 = tf.nn.relu(h2)
y_logits = fc('layer3', 10, h2)


y_hat = tf.nn.softmax(y_logits)

###################################################################
#                    Implementation 3-4                           #
###################################################################
cross_entropy = get_cross_entropy_loss(y_true, y_hat)


# Calculate accuracy
accuracy = get_accuracy(y_true, y_hat)
# Make gradient descent op
train_step = tf.train.AdamOptimizer(learning_rate).minimize(cross_entropy)

# Make op to initialize declared variable
init = tf.global_variables_initializer()

with tf.Session() as sess:
    # Initialize variables
    sess.run(init)
    
    # Training
    for step in range(max_iter):
        # Get batch data and label
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # train the network and calculate cross entropy
        _= sess.run(train_step, feed_dict={x: batch_x, y_true: batch_y}) # w, b 를 update하자
        loss = sess.run(cross_entropy, feed_dict={x: batch_x, y_true: batch_y}) # loss를 확인하자
        
        # calcualte accuracy
        acc = sess.run(accuracy, feed_dict={x: test_data, y_true: test_label})
        # print loss (cross entropy) and accuracy at every 10th step
        if (step + 1) % 10 == 0:
            print("{}th iteration, loss: {:.4f}, test accuracy: {:.4f}".format(step + 1, loss, acc))
# Out:
# 10th iteration, loss: 2.2419, test accuracy: 0.2582
# 20th iteration, loss: 2.0798, test accuracy: 0.4305
# 30th iteration, loss: 1.4975, test accuracy: 0.5659
# 40th iteration, loss: 0.8375, test accuracy: 0.7049
# 50th iteration, loss: 0.9341, test accuracy: 0.7647
# 60th iteration, loss: 0.7063, test accuracy: 0.7824
# 70th iteration, loss: 0.5856, test accuracy: 0.7913
# 80th iteration, loss: 0.5813, test accuracy: 0.8310
# 90th iteration, loss: 0.4145, test accuracy: 0.8427
# 100th iteration, loss: 0.6353, test accuracy: 0.8520
# 110th iteration, loss: 0.4166, test accuracy: 0.8647
# 120th iteration, loss: 0.4589, test accuracy: 0.8725
# 130th iteration, loss: 0.5260, test accuracy: 0.8690
# 140th iteration, loss: 0.5247, test accuracy: 0.8650
# 150th iteration, loss: 0.2391, test accuracy: 0.8811
# 160th iteration, loss: 0.3913, test accuracy: 0.8875
# 170th iteration, loss: 0.3733, test accuracy: 0.8877
# 180th iteration, loss: 0.3603, test accuracy: 0.8902
# 190th iteration, loss: 0.4049, test accuracy: 0.8943
# 200th iteration, loss: 0.3548, test accuracy: 0.8950
# 210th iteration, loss: 0.3122, test accuracy: 0.8918
# 220th iteration, loss: 0.2973, test accuracy: 0.8927
# 230th iteration, loss: 0.3902, test accuracy: 0.8918
# 240th iteration, loss: 0.2636, test accuracy: 0.8984
# 250th iteration, loss: 0.3374, test accuracy: 0.9018
# 260th iteration, loss: 0.3150, test accuracy: 0.9069
# 270th iteration, loss: 0.3385, test accuracy: 0.9050
# 280th iteration, loss: 0.2032, test accuracy: 0.9080
# 290th iteration, loss: 0.3345, test accuracy: 0.9078
# 300th iteration, loss: 0.2014, test accuracy: 0.9099
# 310th iteration, loss: 0.4417, test accuracy: 0.9107
# 320th iteration, loss: 0.2148, test accuracy: 0.9109
# 330th iteration, loss: 0.2653, test accuracy: 0.9131
# 340th iteration, loss: 0.2911, test accuracy: 0.9160
# 350th iteration, loss: 0.2156, test accuracy: 0.9194
# 360th iteration, loss: 0.3976, test accuracy: 0.9187
# 370th iteration, loss: 0.2887, test accuracy: 0.9189
# 380th iteration, loss: 0.3090, test accuracy: 0.9188
# 390th iteration, loss: 0.2719, test accuracy: 0.9214
# 400th iteration, loss: 0.3412, test accuracy: 0.9248
# 410th iteration, loss: 0.1714, test accuracy: 0.9203
# 420th iteration, loss: 0.2334, test accuracy: 0.9234
# 430th iteration, loss: 0.2753, test accuracy: 0.9214
# 440th iteration, loss: 0.1858, test accuracy: 0.9294
# 450th iteration, loss: 0.2647, test accuracy: 0.9287
# 460th iteration, loss: 0.2113, test accuracy: 0.9243
# 470th iteration, loss: 0.1526, test accuracy: 0.9330
# 480th iteration, loss: 0.2232, test accuracy: 0.9303
# 490th iteration, loss: 0.1989, test accuracy: 0.9290
# 500th iteration, loss: 0.1505, test accuracy: 0.9346
# 510th iteration, loss: 0.2134, test accuracy: 0.9317
# 520th iteration, loss: 0.2942, test accuracy: 0.9356
# 530th iteration, loss: 0.2371, test accuracy: 0.9339
# 540th iteration, loss: 0.1665, test accuracy: 0.9330
# 550th iteration, loss: 0.2663, test accuracy: 0.9345
# 560th iteration, loss: 0.2555, test accuracy: 0.9349
# 570th iteration, loss: 0.1932, test accuracy: 0.9316
# 580th iteration, loss: 0.1639, test accuracy: 0.9409
# 590th iteration, loss: 0.1626, test accuracy: 0.9390
# 600th iteration, loss: 0.2227, test accuracy: 0.9397
# 610th iteration, loss: 0.0636, test accuracy: 0.9384
# 620th iteration, loss: 0.1817, test accuracy: 0.9398
# 630th iteration, loss: 0.2242, test accuracy: 0.9405
# 640th iteration, loss: 0.1336, test accuracy: 0.9419
# 650th iteration, loss: 0.2594, test accuracy: 0.9398
# 660th iteration, loss: 0.0818, test accuracy: 0.9432
# 670th iteration, loss: 0.1109, test accuracy: 0.9439
# 680th iteration, loss: 0.1381, test accuracy: 0.9438
# 690th iteration, loss: 0.1137, test accuracy: 0.9435
# 700th iteration, loss: 0.1476, test accuracy: 0.9471
# 710th iteration, loss: 0.1200, test accuracy: 0.9401
# 720th iteration, loss: 0.2192, test accuracy: 0.9409
# 730th iteration, loss: 0.1001, test accuracy: 0.9472
# 740th iteration, loss: 0.1568, test accuracy: 0.9468
# 750th iteration, loss: 0.0822, test accuracy: 0.9479
# 760th iteration, loss: 0.1072, test accuracy: 0.9504
# 770th iteration, loss: 0.0961, test accuracy: 0.9476
# 780th iteration, loss: 0.1076, test accuracy: 0.9474
# 790th iteration, loss: 0.2517, test accuracy: 0.9492
# 800th iteration, loss: 0.2333, test accuracy: 0.9453
# 810th iteration, loss: 0.1644, test accuracy: 0.9482
# 820th iteration, loss: 0.0817, test accuracy: 0.9495
# 830th iteration, loss: 0.1313, test accuracy: 0.9503
# 840th iteration, loss: 0.1174, test accuracy: 0.9510
# 850th iteration, loss: 0.1737, test accuracy: 0.9480
# 860th iteration, loss: 0.1918, test accuracy: 0.9511
# 870th iteration, loss: 0.1664, test accuracy: 0.9533
# 880th iteration, loss: 0.1204, test accuracy: 0.9555
# 890th iteration, loss: 0.1252, test accuracy: 0.9532
# 900th iteration, loss: 0.1291, test accuracy: 0.9527
# 910th iteration, loss: 0.1355, test accuracy: 0.9542
# 920th iteration, loss: 0.1081, test accuracy: 0.9565
# 930th iteration, loss: 0.2485, test accuracy: 0.9532
# 940th iteration, loss: 0.1103, test accuracy: 0.9546
# 950th iteration, loss: 0.1243, test accuracy: 0.9574
# 960th iteration, loss: 0.1098, test accuracy: 0.9550
# 970th iteration, loss: 0.2646, test accuracy: 0.9561
# 980th iteration, loss: 0.1281, test accuracy: 0.9559
# 990th iteration, loss: 0.0708, test accuracy: 0.9544
# 1000th iteration, loss: 0.1164, test accuracy: 0.9555
# 1010th iteration, loss: 0.0854, test accuracy: 0.9569
# 1020th iteration, loss: 0.0404, test accuracy: 0.9536
# 1030th iteration, loss: 0.0416, test accuracy: 0.9584
# 1040th iteration, loss: 0.1103, test accuracy: 0.9577
# 1050th iteration, loss: 0.0743, test accuracy: 0.9509
# 1060th iteration, loss: 0.1212, test accuracy: 0.9537
# 1070th iteration, loss: 0.3711, test accuracy: 0.9563
# 1080th iteration, loss: 0.1672, test accuracy: 0.9579
# 1090th iteration, loss: 0.1228, test accuracy: 0.9582
# 1100th iteration, loss: 0.1278, test accuracy: 0.9582
# 1110th iteration, loss: 0.1781, test accuracy: 0.9580
# 1120th iteration, loss: 0.1645, test accuracy: 0.9613
# 1130th iteration, loss: 0.1356, test accuracy: 0.9610
# 1140th iteration, loss: 0.0568, test accuracy: 0.9610
# 1150th iteration, loss: 0.1010, test accuracy: 0.9605
# 1160th iteration, loss: 0.0763, test accuracy: 0.9567
# 1170th iteration, loss: 0.0396, test accuracy: 0.9621
# 1180th iteration, loss: 0.0941, test accuracy: 0.9618
# 1190th iteration, loss: 0.0572, test accuracy: 0.9597
# 1200th iteration, loss: 0.1204, test accuracy: 0.9621
# 1210th iteration, loss: 0.0787, test accuracy: 0.9609
# 1220th iteration, loss: 0.1832, test accuracy: 0.9607
# 1230th iteration, loss: 0.0724, test accuracy: 0.9626
# 1240th iteration, loss: 0.1224, test accuracy: 0.9615
# 1250th iteration, loss: 0.0916, test accuracy: 0.9604
# 1260th iteration, loss: 0.0851, test accuracy: 0.9585
# 1270th iteration, loss: 0.1216, test accuracy: 0.9635
# 1280th iteration, loss: 0.0991, test accuracy: 0.9636
# 1290th iteration, loss: 0.1066, test accuracy: 0.9625
# 1300th iteration, loss: 0.0472, test accuracy: 0.9611
# 1310th iteration, loss: 0.0974, test accuracy: 0.9639
# 1320th iteration, loss: 0.1436, test accuracy: 0.9644
# 1330th iteration, loss: 0.1284, test accuracy: 0.9630
# 1340th iteration, loss: 0.0841, test accuracy: 0.9646
# 1350th iteration, loss: 0.1036, test accuracy: 0.9646
# 1360th iteration, loss: 0.0532, test accuracy: 0.9660
# 1370th iteration, loss: 0.0471, test accuracy: 0.9667
# 1380th iteration, loss: 0.0677, test accuracy: 0.9619
# 1390th iteration, loss: 0.0741, test accuracy: 0.9650
# 1400th iteration, loss: 0.1227, test accuracy: 0.9634
# 1410th iteration, loss: 0.1027, test accuracy: 0.9645
# 1420th iteration, loss: 0.0322, test accuracy: 0.9631
# 1430th iteration, loss: 0.1351, test accuracy: 0.9638
# 1440th iteration, loss: 0.0815, test accuracy: 0.9640
# 1450th iteration, loss: 0.1180, test accuracy: 0.9653
# 1460th iteration, loss: 0.0522, test accuracy: 0.9679
# 1470th iteration, loss: 0.0958, test accuracy: 0.9658
# 1480th iteration, loss: 0.0993, test accuracy: 0.9663
# 1490th iteration, loss: 0.1897, test accuracy: 0.9655
# 1500th iteration, loss: 0.1175, test accuracy: 0.9640
# 1510th iteration, loss: 0.1348, test accuracy: 0.9679
# 1520th iteration, loss: 0.0986, test accuracy: 0.9671
# 1530th iteration, loss: 0.0899, test accuracy: 0.9685
# 1540th iteration, loss: 0.0848, test accuracy: 0.9630
# 1550th iteration, loss: 0.0881, test accuracy: 0.9674
# 1560th iteration, loss: 0.1995, test accuracy: 0.9670
# 1570th iteration, loss: 0.1280, test accuracy: 0.9681
# 1580th iteration, loss: 0.0863, test accuracy: 0.9675
# 1590th iteration, loss: 0.0958, test accuracy: 0.9629
# 1600th iteration, loss: 0.0865, test accuracy: 0.9675
# 1610th iteration, loss: 0.0593, test accuracy: 0.9689
# 1620th iteration, loss: 0.1050, test accuracy: 0.9698
# 1630th iteration, loss: 0.0404, test accuracy: 0.9684
# 1640th iteration, loss: 0.1297, test accuracy: 0.9671
# 1650th iteration, loss: 0.1324, test accuracy: 0.9652
# 1660th iteration, loss: 0.0579, test accuracy: 0.9647
# 1670th iteration, loss: 0.0618, test accuracy: 0.9647
# 1680th iteration, loss: 0.0669, test accuracy: 0.9690
# 1690th iteration, loss: 0.0221, test accuracy: 0.9674
# 1700th iteration, loss: 0.0991, test accuracy: 0.9691
# 1710th iteration, loss: 0.0712, test accuracy: 0.9683
# 1720th iteration, loss: 0.0379, test accuracy: 0.9697
# 1730th iteration, loss: 0.1260, test accuracy: 0.9676
# 1740th iteration, loss: 0.0340, test accuracy: 0.9692
# 1750th iteration, loss: 0.0912, test accuracy: 0.9690
# 1760th iteration, loss: 0.0376, test accuracy: 0.9691
# 1770th iteration, loss: 0.0894, test accuracy: 0.9692
# 1780th iteration, loss: 0.1181, test accuracy: 0.9694
# 1790th iteration, loss: 0.0900, test accuracy: 0.9665
# 1800th iteration, loss: 0.1124, test accuracy: 0.9699
# 1810th iteration, loss: 0.0455, test accuracy: 0.9708
# 1820th iteration, loss: 0.0748, test accuracy: 0.9701
# 1830th iteration, loss: 0.0884, test accuracy: 0.9710
# 1840th iteration, loss: 0.1096, test accuracy: 0.9719
# 1850th iteration, loss: 0.0684, test accuracy: 0.9708
# 1860th iteration, loss: 0.0277, test accuracy: 0.9722
# 1870th iteration, loss: 0.0520, test accuracy: 0.9710
# 1880th iteration, loss: 0.0685, test accuracy: 0.9707
# 1890th iteration, loss: 0.1544, test accuracy: 0.9700
# 1900th iteration, loss: 0.1056, test accuracy: 0.9671
# 1910th iteration, loss: 0.0913, test accuracy: 0.9689
# 1920th iteration, loss: 0.1030, test accuracy: 0.9705
# 1930th iteration, loss: 0.1379, test accuracy: 0.9723
# 1940th iteration, loss: 0.0948, test accuracy: 0.9721
# 1950th iteration, loss: 0.0926, test accuracy: 0.9708
# 1960th iteration, loss: 0.0512, test accuracy: 0.9667
# 1970th iteration, loss: 0.1009, test accuracy: 0.9677
# 1980th iteration, loss: 0.0403, test accuracy: 0.9694
# 1990th iteration, loss: 0.0333, test accuracy: 0.9719
# 2000th iteration, loss: 0.0320, test accuracy: 0.9712
