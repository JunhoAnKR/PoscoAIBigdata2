# %% [markdown]
# ## 로지스틱 회귀분석

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from sklearn import metrics
from sklearn.preprocessing import scale

# %%
ds_tc = pd.read_csv("실습파일/통신고객이탈.csv" ,engine='python')
ds_tc.head()
# Out:
#     CHURN CUSTOMER_ID GENDER  AGE CHARGE_TYPE  HANDSET USAGE_BAND  \
# 0  Active     K102990      F   31     CAT 100  ASAD170        Med
# 1  Active     K103280      M   27     CAT 100      S50        Med
# 2  Active     K103660      M   27     CAT 100  ASAD170        Med
# 3  Active     K103730      M   61     CAT 100  ASAD170        Med
# 4  Active     K104560      F   52     CAT 100      S50        Med
#
#    SERVICE_DURATION  DROPPED_CALLS  PEAK_CALLS_NO  PEAK_CALLS_TIME  \
# 0             33.33              6            218            379.8
# 1             30.87             10            373            656.4
# 2             49.40             11            260            582.0
# 3             48.60              1            294            661.8
# 4             56.03              0            221            555.6
#
#    WEEKEND_CALLS_NO  WEEKEND_CALLS_TIME  TOTAL_CALLS_NO  TOTAL_CALLS_TIME
# 0                 9                21.6             366             632.4
# ...

# %%
ds_tc.isnull().sum(axis = 0)
# Out:
# CHURN                 0
# CUSTOMER_ID           0
# GENDER                0
# AGE                   0
# CHARGE_TYPE           0
# HANDSET               0
# USAGE_BAND            0
# SERVICE_DURATION      0
# DROPPED_CALLS         0
# PEAK_CALLS_NO         0
# PEAK_CALLS_TIME       0
# WEEKEND_CALLS_NO      0
# WEEKEND_CALLS_TIME    0
# TOTAL_CALLS_NO        0
# TOTAL_CALLS_TIME      0
# dtype: int64

# %%
np.random.seed(1234)
msk = np.random.rand(ds_tc.shape[0],) < 0.7
ds_tc["CHURN"].replace(to_replace = "Active", value = 0, inplace = True)
ds_tc["CHURN"].replace(to_replace = "Churned", value = 1, inplace = True)

ds_tc_train = ds_tc[msk]
ds_tc_test = ds_tc[~msk]

print("train data size:{}".format(ds_tc_train.shape))
print("test data size:{}".format(ds_tc_test.shape))
# Out:
# train data size:(635, 15)
# test data size:(295, 15)

# %%
ds_tc_train = sm.add_constant(ds_tc_train)
ds_tc_train.head()
# Out:
#    const  CHURN CUSTOMER_ID GENDER  AGE CHARGE_TYPE  HANDSET USAGE_BAND  \
# 0    1.0      0     K102990      F   31     CAT 100  ASAD170        Med
# 1    1.0      0     K103280      M   27     CAT 100      S50        Med
# 2    1.0      0     K103660      M   27     CAT 100  ASAD170        Med
# 5    1.0      0     K105530      M   51     CAT 100      S80        Med
# 6    1.0      0     K106210      F   30     CAT 100  ASAD170        Med
#
#    SERVICE_DURATION  DROPPED_CALLS  PEAK_CALLS_NO  PEAK_CALLS_TIME  \
# 0             33.33              6            218            379.8
# 1             30.87             10            373            656.4
# 2             49.40             11            260            582.0
# 5             49.43              3            289            486.6
# 6             32.30              6            427            729.6
#
#    WEEKEND_CALLS_NO  WEEKEND_CALLS_TIME  TOTAL_CALLS_NO  TOTAL_CALLS_TIME
# ...

# %%
log_model_tc = sm.Logit.from_formula(""" CHURN ~ C(GENDER)+ AGE + C(CHARGE_TYPE) 
+ C(HANDSET) + C(USAGE_BAND) + SERVICE_DURATION + DROPPED_CALLS + PEAK_CALLS_NO + PEAK_CALLS_TIME 
+ WEEKEND_CALLS_NO + WEEKEND_CALLS_TIME + TOTAL_CALLS_NO + TOTAL_CALLS_TIME + 1 """, ds_tc_train)

log_result_tc = log_model_tc.fit(method='bfgs')
print(log_result_tc.summary())
# Out:
# ...
#          Current function value: 0.261293
#          Iterations: 35
#          Function evaluations: 49
#          Gradient evaluations: 42
#                            Logit Regression Results
# ...
# Dep. Variable:                  CHURN   No. Observations:                  635
# Model:                          Logit   Df Residuals:                      605
# Method:                           MLE   Df Model:                           29
# Date:                Mon, 11 Feb 2019   Pseudo R-squ.:                  0.4660
# Time:                        17:49:15   Log-Likelihood:                -165.92
# converged:                      False   LL-Null:                       -310.70
#                                         LLR p-value:                 9.369e-45
# ...
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
y_pred_tc = log_result_tc.predict(ds_tc_test)
y_pred_class_tc = (y_pred_tc > .5).astype(int)
y_pred_class_tc.head()
# Out:
# 3    0
# 4    0
# 7    0
# 8    0
# 9    0
# dtype: int64

# %%
print("Accuracy: {0:.3f}".format(metrics.accuracy_score(ds_tc_test["CHURN"], y_pred_class_tc)))
# Out:
# Accuracy: 0.898

# %%
ds_logistic_coef = pd.DataFrame({"Coef": log_result_tc.params.values[1:]}, index = log_model_tc.exog_names[1:])
ds_logistic_coef.plot.barh(y="Coef")

# %%
ds_tc_char = ds_tc.select_dtypes(include="object")
ds_tc_numeric = ds_tc.select_dtypes(exclude = "object")

ds_tc_char_train = ds_tc_char[msk]
ds_tc_numeric_scaled_train = scale(ds_tc_numeric[msk])
ds_tc_numeric_scaled_train = pd.DataFrame(ds_tc_numeric_scaled_train, columns=ds_tc_numeric.columns)
ds_tc_numeric_scaled_train.head()
# Out:
# /home/pirl/anaconda3/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:5: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by the scale function.
#   """
#       CHURN       AGE  SERVICE_DURATION  DROPPED_CALLS  PEAK_CALLS_NO  \
# 0 -0.487665 -0.061287         -0.066658       0.936779      -0.050954
# 1 -0.487665 -0.366521         -0.240702       2.073082       0.618542
# 2 -0.487665 -0.366521          1.070294       2.357157       0.130457
# 3 -0.487665  1.464884          1.072417       0.084552       0.255718
# 4 -0.487665 -0.137596         -0.139530       0.936779       0.851786
#
#    PEAK_CALLS_TIME  WEEKEND_CALLS_NO  WEEKEND_CALLS_TIME  TOTAL_CALLS_NO  \
# 0        -0.622843         -0.431938           -0.777862        0.069711
# 1        -0.088273         -0.309382           -0.601091        0.247156
# 2        -0.232062         -0.983441           -1.374462       -0.328554
# ...

# %%
ds_tc_numeric_scaled_train["CHURN"] = np.where(ds_tc_numeric_scaled_train["CHURN"]>0,1,0)
ds_tc_numeric_scaled_train.head()
# Out:
#    CHURN       AGE  SERVICE_DURATION  DROPPED_CALLS  PEAK_CALLS_NO  \
# 0      0 -0.061287         -0.066658       0.936779      -0.050954
# 1      0 -0.366521         -0.240702       2.073082       0.618542
# 2      0 -0.366521          1.070294       2.357157       0.130457
# 3      0  1.464884          1.072417       0.084552       0.255718
# 4      0 -0.137596         -0.139530       0.936779       0.851786
#
#    PEAK_CALLS_TIME  WEEKEND_CALLS_NO  WEEKEND_CALLS_TIME  TOTAL_CALLS_NO  \
# 0        -0.622843         -0.431938           -0.777862        0.069711
# 1        -0.088273         -0.309382           -0.601091        0.247156
# 2        -0.232062         -0.983441           -1.374462       -0.328554
# 3        -0.416436         -0.922163           -0.496134        0.310247
# 4         0.053197         -0.248104            0.083895        0.558670
#
#    TOTAL_CALLS_TIME
# 0         -0.778293
# 1         -0.454921
# 2         -0.811538
# 3         -0.286151
# ...

# %%
ds_tc_scaled_train = pd.concat([ds_tc_numeric_scaled_train, ds_tc_char_train.reset_index(drop= True)], axis=1)

# %%
scaled_log_model = sm.Logit.from_formula(""" CHURN ~ C(GENDER)+ AGE + C(CHARGE_TYPE) 
+ C(HANDSET) + C(USAGE_BAND) + SERVICE_DURATION + DROPPED_CALLS + PEAK_CALLS_NO + PEAK_CALLS_TIME 
+ WEEKEND_CALLS_NO + WEEKEND_CALLS_TIME + TOTAL_CALLS_NO + TOTAL_CALLS_TIME + 1 """, ds_tc_scaled_train)

scaled_log_result = scaled_log_model.fit(method='bfgs')

ds_logg_scaled_coef = pd.DataFrame({'Coef': scaled_log_result.params.values[1:]},
                                  index = scaled_log_model.exog_names[1:])
ds_logg_scaled_coef.plot.barh(y="Coef", legend = False)
# Out:
# ...
#          Current function value: 0.262450
#          Iterations: 35
#          Function evaluations: 36
#          Gradient evaluations: 36
# /home/pirl/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %% [markdown]
# ## 의사결정나무 숙제

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
import graphviz
from IPython.display import display

# %matplotlib inline

# %%
from sklearn.model_selection import GridSearchCV

# %%
df = pd.read_csv("실습파일/유방암.csv", engine = 'python')
df.head()
# Out:
#    diagnosis  mean radius  mean texture  mean perimeter  mean area  \
# 0          0        17.99         10.38          122.80     1001.0
# 1          0        20.57         17.77          132.90     1326.0
# 2          0        19.69         21.25          130.00     1203.0
# 3          0        11.42         20.38           77.58      386.1
# 4          0        20.29         14.34          135.10     1297.0
#
#    mean smoothness  mean compactness  mean concavity  mean concave points  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    mean symmetry           ...             worst radius  worst texture  \
# ...

# %%
df_dummy = pd.get_dummies(df)
df_dummy.head()
# Out:
#    diagnosis  mean radius  mean texture  mean perimeter  mean area  \
# 0          0        17.99         10.38          122.80     1001.0
# 1          0        20.57         17.77          132.90     1326.0
# 2          0        19.69         21.25          130.00     1203.0
# 3          0        11.42         20.38           77.58      386.1
# 4          0        20.29         14.34          135.10     1297.0
#
#    mean smoothness  mean compactness  mean concavity  mean concave points  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    mean symmetry           ...             worst radius  worst texture  \
# ...

# %%
msk = np.random.rand(df_dummy.shape[0]) < 0.7
df_train =df_dummy[msk]
df_test =df_dummy[~msk]
df_train.head()
# Out:
#    diagnosis  mean radius  mean texture  mean perimeter  mean area  \
# 0          0        17.99         10.38          122.80     1001.0
# 2          0        19.69         21.25          130.00     1203.0
# 3          0        11.42         20.38           77.58      386.1
# 4          0        20.29         14.34          135.10     1297.0
# 5          0        12.45         15.70           82.57      477.1
#
#    mean smoothness  mean compactness  mean concavity  mean concave points  \
# 0           0.1184            0.2776          0.3001              0.14710
# 2           0.1096            0.1599          0.1974              0.12790
# 3           0.1425            0.2839          0.2414              0.10520
# 4           0.1003            0.1328          0.1980              0.10430
# 5           0.1278            0.1700          0.1578              0.08089
#
#    mean symmetry           ...             worst radius  worst texture  \
# ...

# %%
df.isnull().sum()
# Out:
# diagnosis                  0
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# dtype: int64

# %%
df_train_y = df_train["diagnosis"]
df_train_x = df_train.drop("diagnosis", axis = 1, inplace = False)
df_test_y = df_test["diagnosis"]
df_test_x = df_test.drop("diagnosis", axis = 1, inplace = False)

print("train data X size:{}".format(df_train_x.shape))
print("train data Y size:{}".format(df_train_y.shape))
print("test data X size:{}".format(df_test_x.shape))
print("test data Y size:{}".format(df_test_y.shape))
# Out:
# train data X size:(402, 30)
# train data Y size:(402,)
# test data X size:(167, 30)
# test data Y size:(167,)

# %%
df_train_labels = df_train["diagnosis"]

parameters = {'min_samples_split':np.arange(2, 80), 'max_depth': np.arange(2,10), 'criterion':['gini', 'entropy']} 

clfr = DecisionTreeClassifier(random_state=1234)

grid = GridSearchCV(clfr, parameters,scoring='accuracy', cv=8) 
grid.fit(df_train_x, df_train_labels) 

print('The parameters combination that would give best accuracy is : ') 
print(grid.best_params_) 
print('The best accuracy achieved after parameter tuning via grid search is : ', grid.best_score_)
# Out:
# The parameters combination that would give best accuracy is :
# {'criterion': 'entropy', 'max_depth': 4, 'min_samples_split': 2}
# The best accuracy achieved after parameter tuning via grid search is :  0.9353233830845771
# /home/pirl/anaconda3/envs/py35/lib/python3.5/site-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
grid.fit(df_train_x, df_train_y).score(df_test_x, df_test_y)
# Out:
# /home/pirl/anaconda3/envs/py35/lib/python3.5/site-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# 0.9281437125748503

# %%
# The parameters combination that would give best accuracy is : 
# {'max_depth': 4, 'min_samples_split': 5, 'criterion': 'entropy'}
best_tree = DecisionTreeClassifier(max_depth = 4, min_samples_split = 2,criterion = 'entropy' , random_state=1234)

best_tree.fit(df_test_x, df_test_y)

export_graphviz(best_tree, out_file="best_tree.dot", class_names=["0", "1"],
               feature_names = df_train_x.columns, impurity = False, filled=True)

with open("best_tree.dot") as f:
    dot_graph = f.read()
display(graphviz.Source(dot_graph))

# %%
import matplotlib.font_manager as fm
import matplotlib
import matplotlib.pyplot as plt
for f in fm.fontManager.ttflist:
    if 'NanumBarunGothic' in f.fname: plt.rcParams['font.family']='NanumBarunGothic'
    # 폰트 나눔고딕으로

print(plt.rcParams['font.family'])

matplotlib.rcParams['axes.unicode_minus'] = False # '-'기호 제대로 나오게
# Out:
# ['NanumBarunGothic']

# %%
def plot_feature_importances(model):
    n_features = df_train_x.shape[1]
    plt.barh(range(n_features), model.feature_importances_, align="center")
    plt.yticks(np.arange(n_features), df_train_x.columns)
    plt.xlabel("설명변수 중요도")
    plt.ylabel("설명변수")
    plt.ylim(-1, n_features)
    
plot_feature_importances(best_tree)
