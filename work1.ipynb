# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.random.seed(seed= 1234)
normal = np.random.normal(20, 2, 100000)
sns.distplot(normal)

# %%
normal = stats.norm(20,2)
xx = np.linspace(10, 30, 400)
plt.plot(xx, normal.pdf(xx))

# %%
normal = stats.norm(loc=20,scale=2) # loc: 평균, scale:표준편차
xx = np.linspace(10, 30, 400) # np.linspace(start, end, num_points)
plt.plot(xx, normal.pdf(xx)) # pdf: 확률밀도함수 , cdf, ppf: inverse cdf, rvs: random variable sampling

# %%
normal3 = stats.norm(loc=115, scale=20)
xx = np.linspace(60, 170, 400)
plt.plot(xx,normal3.pdf(xx))
x=135
v2 = stats.norm.cdf(x, 115, 20)
print("{0}분이상 걸리는 AS작업비율 : {1: .1f}%".format(x,(1-v2)*100))
v3 = stats.norm.sf(x, 115, 20)
print("{0}분이상 걸리는 AS작업비율 : {1: .1f}%".format(x,v3*100))
v2
inverse = stats.norm.ppf(v2, loc=115, scale=20)
inverse
# Out:
# 135분이상 걸리는 AS작업비율 :  15.9%
# 135분이상 걸리는 AS작업비율 :  15.9%
# 135.0

# %%
# 실습 1.

normal4 = stats.norm(loc=175, scale=5)
xx = np.linspace(160, 190, 400)
plt.plot(xx,normal4.pdf(xx))
x=180
v3 = stats.norm.cdf(x, 175, 5)
print("{0}의 키는 상위 {1: .1f}%".format(x,(1-v3)*100))
# Out:
# 180의 키는 상위  15.9%

# %%
# 실습 2.
normal5 = stats.norm(loc = 12, scale = 3)
xx = np.linspace(3, 21, 400)
plt.plot(xx, normal5.pdf(xx))
num1 = 12
num2 = 15
num3 = 9

v1 = stats.norm.cdf(num1, 12, 3)
v2 = stats.norm.cdf(num2, 12, 3)
v3 = stats.norm.cdf(num3, 12, 3)

print("1리터를 가지고 {0} 이상 {1} 이하를 달릴 확률은 : {2: .1f}".format(num1, num2, (v2-v1)*100))
print("1리터를 가지고 {0} 이상 {1} 이하를 달릴 확률은 : {2: .1f}".format(num3, num2, (v2-v3)*100))
print("1리터를 가지고 {0} 이상 달릴 확률은 : {1: .1f}".format(num2, (1-v2)*100))
# Out:
# 1리터를 가지고 12 이상 15 이하를 달릴 확률은 :  34.1
# 1리터를 가지고 9 이상 15 이하를 달릴 확률은 :  68.3
# 1리터를 가지고 15 이상 달릴 확률은 :  15.9

# %%
# 실습 3. 표준정규분포
normal6 = stats.norm(0, 1)
xx= np.linspace(-3,3,400)
plt.plot(xx , normal6.pdf(xx))

# %%
# T-분포
np.random.seed(seed=1234)
xx = np.linspace(-4, 4, 400)
for df in [1, 5, 25]:
    t_df = stats.t(df=df)
    plt.plot(xx, t_df.pdf(xx))
plt.plot(xx, stats.norm.pdf(xx), lw= 5)

# %%
# 실습 4. 확률변수 t는 자유도가 5인 t-분포를 따른다. P(T <= t)를 계산하시오
t = 1.53
df = 5
prop = stats.t.cdf(t, df)
print("P(T<={0}): {1: .3f}".format(t,prop))
# Out:
# P(T<=1.53):  0.907

# %%
# 실습 5.
t = 2.0
df = 10
prop = stats.t.cdf(t, df)
print("P(T<={0}) : {1: .3f}".format(t, prop))
# Out:
# P(T<=2.0) :  0.963

# %%
np.random.seed(seed=1234)
t_df29 = np.random.standard_t(df = 29, size = 1000)
sns.distplot(t_df29, fit = stats.norm, kde = True)

# %%
np.random.seed(seed=1234)
t_df10 = np.random.standard_t(df = 10, size = 1000)
sns.distplot(t_df10, fit = stats.norm, kde = False)

# %%
# 그림 얹기
np.random.seed(seed=1234)
t_df29 = np.random.standard_t(df = 29, size = 1000)
t_df10 = np.random.standard_t(df = 10, size = 1000)
sns.distplot(t_df29, kde = True)
sns.distplot(t_df10, kde = True)

# %%
# answer
np.random.seed(seed=1234)
t_df10 = np.random.standard_t(df = 10, size = 1000)
sns.distplot(t_df10, fit =stats.norm, kde= False)

t_df = stats.t(df = 10)
xx = np.linspace(-4,4,400)
plt.plot(xx, t_df.pdf(xx))

# %%
np.random.seed(1234)
xx2 = np.linspace(0,100,400)
for df in [1,3,5,7,9,11,15,50]:
    chisq = stats.chi2(df = df)
    plt.plot(xx2, chisq.pdf(xx2))

# %%
np.random.seed(seed=1234)
chisq_df10 = np.random.chisquare(df = 10, size = 1000)
sns.distplot(chisq_df10, fit = stats.norm, kde = True) # kde : kernel density estimate : 여러개의 정규분포를 가정해서 실질적 형상에 가깝게 그려줌

# %%
np.random.seed(seed=1234)
chisq_df40 = np.random.chisquare(df = 40, size = 1000)
sns.distplot(chisq_df40, fit = stats.norm,kde = False)

# %%
# 실습 6. Chisq
np.random.seed(1234)
chisq = 10
df = 30

prop = stats.chi2.cdf(chisq, df)
print("P(T<={0}) : {1: .4f}".format(chisq, prop))
prop2 = stats.chi2.sf(chisq, df)
print("P(T>={0}) : {1: .4f}".format(chisq, prop2))
ppf = stats.chi2(df = df).ppf(prop)
print(ppf)

plt.plot(xx2, stats.chi2(df=df).pdf(xx2))
# Out:
# P(T<=10) :  0.0002
# P(T>=10) :  0.9998
# 10.000000000000155

# %%
# 실습 7. Chisq
np.random.seed(1234)
chisq = 3.0
df = 8

prop = stats.chi2.cdf(chisq, df)
print("P(T<={0}) : {1: .4f}".format(chisq, prop))
prop2 = stats.chi2.sf(chisq, df)
print("P(T>={0}) : {1: .4f}".format(chisq, prop2))
# Out:
# P(T<=3.0) :  0.0656
# P(T>=3.0) :  0.9344

# %%
np.random.seed(1234)
xx = np.linspace(0, 10, 400)
for df in [1,3,5,7,9,30]:
    f_df = stats.f(dfn=df, dfd =10)
    plt.plot(xx, f_df.pdf(xx))
# Out:
# /home/pirl/anaconda3/envs/py35/lib/python3.5/site-packages/scipy/stats/_continuous_distns.py:1679: RuntimeWarning: divide by zero encountered in log
#   lPx = m/2 * np.log(m) + n/2 * np.log(n) + (n/2 - 1) * np.log(x)

# %%
f =2 
dfnum = 15
dfden = 15

prop = stats.f.cdf(x=f,dfn = dfnum, dfd = dfden)
print("P(F<={0}) : {1: .3f}".format(f, prop))

prop2 = stats.f.sf(x=f,dfn = dfnum, dfd = dfden)
print("P(F>={0}) : {1: .3f}".format(f, prop2))

ppf = stats.f(dfn = dfnum, dfd=dfden).ppf(prop)
print(ppf)
# Out:
# P(F<=2) :  0.904
# P(F>=2) :  0.096
# 1.999999999999999

# %%
np.random.seed(1234)
f_df10 = np.random.f(dfnum = 10, dfden=10, size=1000)
sns.distplot(f_df10, fit = stats.f ,kde = True)

f_dist = stats.f(dfn = 10, dfd = 10)

xx = np.linspace(0,4,400)
plt.plot(xx,f_dist.pdf(xx))
# Out:
# /home/pirl/anaconda3/envs/py35/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py:2316: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# /home/pirl/anaconda3/envs/py35/lib/python3.5/site-packages/scipy/stats/_continuous_distns.py:1679: RuntimeWarning: divide by zero encountered in log
#   lPx = m/2 * np.log(m) + n/2 * np.log(n) + (n/2 - 1) * np.log(x)

# %%
np.random.seed(1234)
xx = np.linspace(0, 3000, 400)
for c in [1,3,5,25,50]:
    weibull_df = stats.weibull_min(c=c, scale=1200)
    plt.plot(xx, weibull_df.pdf(xx))

# %%
# 실습 와이블
np.random.seed(1234)
x = 1500
alpha = 2.2
beta = 1200

prop = stats.weibull_min.cdf(x, c = alpha, scale = beta)
print("P(x>={0}) : {1: .5f}".format(x, (1-prop)))
# Out:
# P(x>=1500) :  0.19518
# 0.19518415119971322

# %%
n = 3
for i in range(n+1):
    prop = stats.binom.pmf(k = i, n=n, p = 0.4)
    print("P(X={0}) : {1: .3f}".format(i, prop))
# Out:
# P(X=0) :  0.216
# P(X=1) :  0.432
# P(X=2) :  0.288
# P(X=3) :  0.064

# %%
for n in [3, 5, 25, 50]:
    binorm2 = stats.binom(n=n, p=0.4)
    xx=np.linspace(0, n, n+1)
    plt.plot(xx, binorm2.pmf(xx))

# %%
for mu in [2,4,6,10]:
    poisson_df = stats.poisson(mu = mu)
    xx = np.linspace(0, 3*mu, 3*mu+1)
    plt.plot(xx, poisson_df.pmf(xx))

# %%
mu = 2
prop = stats.poisson.pmf(3, mu)

cdf_prop = stats.poisson.cdf(2, mu)
print("1분당 {0}번의 전화가 걸려올 확률: {1: .4f}".format(mu, prop))
print("1분당 최대 {0}번 이하의 전화가 걸려올 확률: {1: .4f}".format(mu, cdf_prop))
# Out:
# 1분당 2번의 전화가 걸려올 확률:  0.1804
# 1분당 최대 2번 이하의 전화가 걸려올 확률:  0.6767

# %%
ds_mycars = pd.read_csv("실습파일/mycars.csv", engine = "python")
df = ds_mycars[['model', 'mpg']]
df.groupby('model').describe()
# Out:
#                          mpg                                                 \
#                        count       mean       std   min    25%   50%    75%
# model
# 4runner 4wd              6.0  15.166667  0.752773  14.0  15.00  15.0  15.75
# a4                       7.0  18.857143  1.864454  16.0  18.00  18.0  20.50
# a4 quattro               8.0  17.125000  1.807722  15.0  15.75  17.0  18.25
# a6 quattro               3.0  16.000000  1.000000  15.0  15.50  16.0  16.50
# altima                   6.0  20.666667  1.966384  19.0  19.00  20.0  22.50
# c1500 suburban 2wd       5.0  12.800000  1.303840  11.0  12.00  13.0  14.00
# camry                    7.0  19.857143  1.463850  18.0  18.50  21.0  21.00
# camry solara             7.0  19.857143  1.772811  18.0  18.00  21.0  21.00
# caravan 2wd             11.0  15.818182  1.834022  11.0  15.50  16.0  17.00
# civic                    9.0  24.444444  1.943651  21.0  24.00  24.0  25.00
# ...

# %%
ds_mycars.head()
# Out:
#   manufacturer model  displacement  year  cylinder automatic driving  mpg  \
# 0         audi    a4           1.8  1999         4      auto       f   18
# 1         audi    a4           1.8  1999         4    manual       f   21
# 2         audi    a4           2.0  2008         4    manual       f   20
# 3         audi    a4           2.0  2008         4      auto       f   21
# 4         audi    a4           2.8  1999         6      auto       f   16
#
#    highway_mileage fuel    class
# 0               29    p  compact
# 1               29    p  compact
# 2               31    p  compact
# 3               30    p  compact
# 4               26    p  compact

# %%
ds_mycars['mpg'].mean()
# Out:
# 16.858974358974358

# %%
ds_mycars['mpg'].std()
# Out:
# 4.255945678889395

# %%
ds_mycars[['mpg', 'displacement']].mean()
# Out:
# mpg             16.858974
# displacement     3.471795
# dtype: float64

# %%
ds_mycars.mean()
# Out:
# displacement          3.471795
# year               2003.500000
# cylinder              5.888889
# mpg                  16.858974
# highway_mileage      23.440171
# dtype: float64

# %%
ds_mycars.groupby('mpg').mean()
# Out:
#      displacement         year  cylinder  highway_mileage
# mpg
# 9        4.700000  2008.000000  8.000000        12.000000
# 11       5.150000  2000.800000  7.900000        15.550000
# 12       5.050000  2008.000000  8.000000        17.375000
# 13       4.833333  2005.000000  7.619048        17.428571
# 14       4.557895  2003.736842  7.052632        18.105263
# 15       3.970833  2002.000000  6.416667        20.875000
# 16       3.678947  2003.263158  6.105263        23.368421
# 17       3.143750  2005.187500  5.875000        24.500000
# 18       2.815385  2000.730769  5.307692        26.192308
# 19       2.565000  2003.050000  4.600000        26.450000
# 20       2.318182  2008.000000  4.181818        27.545455
# 21       2.173913  2003.695652  4.086957        29.130435
# 22       2.200000  2008.000000  4.000000        29.750000
# 23       2.200000  2005.000000  4.000000        30.666667
# 24       1.720000  2000.800000  4.000000        32.600000
# ...

# %%
ds_mycars[['mpg', 'cylinder']].groupby('cylinder').mean()
# Out:
#                 mpg
# cylinder
# 4         21.012346
# 5         20.500000
# 6         16.215190
# 8         12.571429

# %%
ds_mycars.mpg.mean()
# Out:
# 16.858974358974358

# %%
ds_mycars.mpg.describe()
# Out:
# count    234.000000
# mean      16.858974
# std        4.255946
# min        9.000000
# 25%       14.000000
# 50%       17.000000
# 75%       19.000000
# max       35.000000
# Name: mpg, dtype: float64

# %%
ds_EXH_QC1 = pd.read_csv("실습파일/EXH_QC1.csv", engine = "python")

# %%
ds_EXH_QC1.head()
# Out:
#      Flaws Period  Strength  Baking Time  Cabbage weight
# 0  Scratch    Day      37.6     0.798922             3.6
# 1  Scratch    Day      38.6     0.849020             2.9
# 2     Peel    Day      37.2     0.816163             2.8
# 3     Peel    Day      36.4     0.758266             2.6
# 4   Smudge    Day      38.6     0.815894             3.4

# %%
df = ds_EXH_QC1[['Flaws', 'Period']]
count = df['Flaws'].value_counts().sort_index()
count
# Out:
# Other       6
# Peel       15
# Scratch    13
# Smudge      6
# Name: Flaws, dtype: int64

# %%
cumcnt= np.cumsum(count)
print(cumcnt)
# Out:
# Other       6
# Peel       21
# Scratch    34
# Smudge     40
# Name: Flaws, dtype: int64

# %%
percent = count/sum(count)*100
print(percent)
# Out:
# Other      15.0
# Peel       37.5
# Scratch    32.5
# Smudge     15.0
# Name: Flaws, dtype: float64

# %%
cumpct = np.cumsum(percent)
print(cumpct)
# Out:
# Other       15.0
# Peel        52.5
# Scratch     85.0
# Smudge     100.0
# Name: Flaws, dtype: float64

# %%
count_data = pd.DataFrame({'Count': count, 'CumCnt': cumcnt, 'Percent': percent, 'CumPct': cumpct})
count_data
# Out:
#          Count  CumCnt  CumPct  Percent
# Other        6       6    15.0     15.0
# Peel        15      21    52.5     37.5
# Scratch     13      34    85.0     32.5
# Smudge       6      40   100.0     15.0

# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.stats.proportion import proportions_ztest
from sklearn import linear_model

# %%
ds_exm = pd.read_csv("실습파일/EXH_QC.csv", engine = "python")
df = ds_exm[['Cabbage weight']]
lower, upper = stats.norm.interval(0.95, loc=2.7, scale = 0.397/np.sqrt(40))
print("신뢰구간: ({0}, {1})".format(lower.round(2), upper.round(2)))
# Out:
# 신뢰구간: (2.58, 2.82)

# %%
df = pd.DataFrame({'sample' :[74.5, 81.2,73.8,82.0,76.3,75.7,80.2,72.6,77.9,82.8]})
t_result = stats.ttest_1samp(df, 76.7)
t, p = t_result.statistic.round(3), t_result.pvalue.round(3)
print("1-sample t-test")
print("t검정통계량: {}".format(t))
print("p-value : {}".format(p))
# Out:
# 1-sample t-test
# t검정통계량: [0.864]
# p-value : [0.41]

# %%
df1 =pd.DataFrame({'A': [892,623,721,678,723,790,720,670,690,771]})
df2 =pd.DataFrame({'B': [721,821,910,678,723,790,711,790,745,891]})
df3 =pd.DataFrame({'C': [621,915,888,721,894,834,841,912,845,889]})
f_test=stats.f_oneway(df1, df2, df3)
f , p = f_test.statistic.round(3), f_test.pvalue.round(3)
print("one way ANOVA")
print("F: {}".format(f))
print("p: {}".format(p))
# Out:
# one way ANOVA
# F: [4.263]
# p: [0.025]
